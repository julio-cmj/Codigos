# %% [markdown]
# # Resultados dos experimentos até agora

# %%
import numpy as np
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.visualization import plot_histogram
service = QiskitRuntimeService()

# %% [markdown]
# ## Modelo mínimo:

# %% [markdown]
# h = 1, k = 0.2

# %%
# Sampler
jobS = service.job('czzxtpjnhqag008v1a2g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc240rxz8g008axkyg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.2;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.12138067569091998 ± 0.007235680479402059
# Estimated B = 0.06040868527774412 ± 0.011542361870063593

# %%
# Sampler
jobS = service.job('czzxtmtkzhn0008dhhwg')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc2t3d8drg008zdqjg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 0.2;
n_shots = 5000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.07307354594472643 ± 0.005656635211855189
# Estimated V = -0.07158153279641122 ± 0.004899328098377514

# %% [markdown]
# h = 1, k = 0.5

# %%
# Sampler
jobS = service.job('czzxtt36rr3g008mrang')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc2vbrxz8g008axm5g')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.5;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.24202719099991576 ± 0.010717968464219326
# Estimated B = 0.20495367407051546 ± 0.013263249801574997

# %%
# Sampler
jobS = service.job('czzxtrbrxz8g008febe0')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc344nhqag008q88qg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 0.5;
n_shots = 5000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.258386404500042 ± 0.014132347009608841
# Estimated V = -0.2659883070757387 ± 0.06376810333108925

# %% [markdown]
# h = 1, k = 1

# %%
# Sampler
jobS = service.job('czzxtx3nhqag008v1a5g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc35cnhqag008q88s0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.28510678118654736 ± 0.012821201191776066
# Estimated B = 0.23817764770505379 ± 0.0046884892794179355

# %%
# Sampler
joBS = service.job('czzxtvknhqag008v1a40')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc36m6rr3g0087zwv0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 1;
n_shots = 5000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 1.382213562373095 ± 0.025642402383552133
# Estimated V = -0.30935575399969717 ± 0.041582146888657245

# %% [markdown]
# h = 1, k = 1.5

# %%
# Sampler
jobS = service.job('czzxtzbd8drg008j5e20')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc3mekzhn0008w1xcg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1.5;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = -0.01009980377477089 ± 0.011670483794599092
# Estimated B = 0.29164785640162905 ± 0.04190872736461174

# %%
# Sampler
jobS = service.job('czzxtybnhqag008v1a7g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc3yqkzhn0008w1xf0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 1.5;
n_shots = 5000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 0.14535088301353127 ± 0.04240301838312927
# Estimated V = -0.3425252923991393 ± 0.0010742098886092047

# %% [markdown]
# h = 1.5, k = 1

# %%
# Sampler
jobS = service.job('d03jjs3d8drg008jqe6g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc3hpnhqag008q88vg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1.5; k = 1;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.7728754415067656 ± 0.02012056142357862
# Estimated B = 0.3710097796856382 ± 0.0944966606179761

# %%
# Sampler
jobS = service.job('d03jjqarxz8g008g0pe0')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dc3k6d8drg008zdqwg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1.5;k = 1;
n_shots = 5000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.7329996075495417 ± 0.028278385243857188
# Estimated V = -0.46922837247734983 ± 0.046577335084385094

# %% [markdown]
# ## Modelo de teleporte a longas distâncias

# %% [markdown]
# h = 1, k = 0.2

# %%
# Sampler
jobS = service.job('d03jaqanhqag008vkeeg') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcqk6rxz8g008axspg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.2;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.11058067569092007 ± 0.0069728043139041275
# Estimated B = 0.13975658694290105 ± 0.010823158630619417

# %%
# Sampler
jobS = service.job('d03jap2nhqag008vkee0')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcqmpqnmvg0087t170')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.2;
n_shots = 5000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 0.010766454055273617 ± 0.005575292236286812
# Estimated V = -0.0169476094042965 ± 0.008341776055408383

# %% [markdown]
# h = 1, k = 0.5

# %%
# Sampler
Job = service.job('d03jasvqnmvg0082byd0') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcqny6rr3g0088021g')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.5;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{Job.backend().name} - H")
# Out:
# H_B = 0.9100271909999158 ± 0.014140414703961128
# Estimated B = 0.21916459586814652 ± 0.010830328697734199

# %%
# Sampler
jobS = service.job('d03jarknhqag008vkef0')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcqwfrxz8g008axsv0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.5;
n_shots = 5000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 0.027213595499957943 ± 0.012834328965707558
# Estimated V = -0.013838356742701008 ± 0.014995621406482681

# %% [markdown]
# h = 1, k = 1

# %%
# Sampler
jobS = service.job('d03jawk6rr3g008s82dg') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0byw1gqnmvg0087fsj0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.15630678118654753 ± 0.011803553363288529
# Estimated B = 0.26240227562774115 ± 0.015668315770563164

# %%
# Extract results
jobS = service.job('d03javbrxz8g008g0n50')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0byhhy6rr3g0087np90')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1;
n_shots = 5000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 0.6790135623730946 ± 0.026303919707906655
# Estimated V = -0.29532263456872343 ± 0.014083987282820981

# %% [markdown]
# h = 1.5, k = 1

# %%
# Extract results
jobS = service.job('d03jayvrxz8g008g0n60') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcrbhqnmvg0087t1e0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1.5; k = 1;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.22447544150676557 ± 0.015506405386162195
# Estimated B = 0.34315493625948357 ± 0.017950757035883693

# %%
# Sampler
jobS = service.job('d03jaxv6rr3g008s82eg')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcrcsnhqag008q8et0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1.5; k = 1;
n_shots = 5000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 0.0990003924504583 ± 0.02440939097970287
# Estimated V = 0.1742021376063675 ± 0.02315185076951275

# %% [markdown]
# h = 1; k = 1.5

# %%
# Sampler
jobS = service.job('d03jg4grxz8g008g0p1g') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcre16rr3g008802a0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1.5;
n_shots = 5000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.12670019622522916 ± 0.01278136142983211
# Estimated B = 0.22881918068904122 ± 0.01553251999002194

# %%
# Extract results
jobS = service.job('d03jg38rxz8g008g0p0g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0dcrqjnhqag008q8ew0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1.5;
n_shots = 5000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# ---------------------------------------------------------------------------
# RuntimeInvalidStateError                  Traceback (most recent call last)
# Cell In[61], line 8
#       6 # Estimator
#       7 jobT = service.job('d0dcrqjnhqag008q8ew0')
# ----> 8 result = jobT.result()[0]
#       9 exp_value = result.data.evs
#      10 value_error = result.data.stds
#
# File c:\Users\julio\AppData\Local\Programs\Python\Python313\Lib\site-packages\qiskit_ibm_runtime\runtime_job_v2.py:139, in RuntimeJobV2.result(self, timeout, decoder)
#     137     raise RuntimeJobFailureError(f"Unable to retrieve job result. {error_message}")
#     138 if self._status == "CANCELLED":
# --> 139     raise RuntimeInvalidStateError(
#     140         "Unable to retrieve result for job {}. " "Job was cancelled.".format(self.job_id())
#     141     )
#     143 result_raw = self._api_client.job_results(job_id=self.job_id())
#     145 return _decoder.decode(result_raw) if result_raw else None
#
# RuntimeInvalidStateError: 'Unable to retrieve result for job d0dcrqjnhqag008q8ew0. Job was cancelled.'
