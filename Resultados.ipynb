# %% [markdown]
# # Resultados dos experimentos até agora

# %%
import numpy as np
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit.visualization import plot_histogram
service = QiskitRuntimeService()

# %% [markdown]
# ## Modelo mínimo:

# %% [markdown]
# h = 1, k = 0.2

# %%
# Sampler
jobS = service.job('d0rmj1emu1ms73d4nm50')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0thosemu1ms73d6kbbg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.2;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.09791400902425343 ± 0.008580978101894048
# Estimated B = 0.06734072336756258 ± 0.007705112232686821

# %%
# Sampler
jobS = service.job('d0rmj1mmu1ms73d4nm5g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0rnqn6mu1ms73d4ovf0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 0.2;
n_shots = 3000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.05915354594472638 ± 0.007302381549624499
# Estimated V = -0.06979672336278067 ± 0.0036999858371106493

# %% [markdown]
# h = 1, k = 0.5

# %%
# Sampler
jobS = service.job('d0rmj1q4p3dc73f1ib0g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0thou6mu1ms73d6kbdg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.5;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.23176052433324917 ± 0.013673245029239752
# Estimated B = 0.18975607950111784 ± 0.01107131471834679

# %%
# Sampler
jobS = service.job('d0rmj2emu1ms73d4nm6g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0rnqofp51os73av8fmg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 0.5;
n_shots = 3000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.17345307116670872 ± 0.018254237458332385
# Estimated V = -0.24848289246773086 ± 0.0181813952492874

# %% [markdown]
# h = 1, k = 1

# %%
# Sampler
jobS = service.job('d0rmj2g7m9ds739fdo80')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0thova4p3dc73f3etg0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.3197734478532141 ± 0.016832239788462384
# Estimated B = 0.26860050494108517 ± 0.018538774301034063

# %%
# Sampler
joBS = service.job('d0rmj2umu1ms73d4nm90')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0rnqpq4p3dc73f1jk0g')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 1;
n_shots = 3000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 1.3622135623730953 ± 0.03366447957692477
# Estimated V = -0.3934578077185207 ± 0.059134677310743

# %% [markdown]
# h = 1, k = 1.5

# %%
# Sampler
jobS = service.job('d0rmj3q4p3dc73f1ib50')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0thp224p3dc73f3etjg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1.5;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.2600335295585625 ± 0.017446791066511876
# Estimated B = 0.3026426652807493 ± 0.013746427459587734

# %%
# Sampler
jobS = service.job('d0rmj4fp51os73av76h0')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0rnqsfp51os73av8fsg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1;k = 1.5;
n_shots = 3000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.053849116986468645 ± 0.0547707829656165
# Estimated V = -0.3931642704492222 ± 0.008764802942406114

# %% [markdown]
# h = 1.5, k = 1

# %%
# Sampler
jobS = service.job('d0rmj3fp51os73av76e0')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0thp0vp51os73b13o70')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1.5; k = 1;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[1]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.3590754415067656 ± 0.022058097530536645
# Estimated B = 0.3252206680170475 ± 0.012188583301122718

# %%
# Sampler
jobS = service.job('d0rmj3np51os73av76fg')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0rnqr7p51os73av8fp0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# Parameters 
h = 1.5;k = 1;
n_shots = 3000

# Energies
ene_V = (2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Erros arrays
error_V = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[1])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**(int(bit_string[1])))

# Print results
print("V =",ene_V,"±",np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.32126627421620846 ± 0.036513855310411
# Estimated V = -0.4533513835109855 ± 0.02641219835907835

# %% [markdown]
# ## Modelo de teleporte a longas distâncias

# %% [markdown]
# h = 1, k = 0.2

# %%
# Sampler
jobS = service.job('d0t7fdq4p3dc73f34ivg') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh0iq9bic73baha80')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.2;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.19658067569092016 ± 0.011333490194992892
# Estimated B = 0.09174902991227207 ± 0.024885905383775008

# %%
# Sampler
jobS = service.job('d0t7fe6mu1ms73d69uug')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh1aq9bic73baha9g')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.2;
n_shots = 3000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.0503535459447264 ± 0.006914008967306883
# Estimated V = 0.006257994350223298 ± 0.02854609747120906

# %% [markdown]
# h = 1, k = 0.5

# %%
# Sampler
Job = service.job('d0t7fenp51os73b0pe10') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh20hmjts73cre2mg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.5;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{Job.backend().name} - H")
# Out:
# H_B = 0.8697605243332492 ± 0.018251863425922256
# Estimated B = 0.17724645147430051 ± 0.05698032450274062

# %%
# Sampler
jobS = service.job('d0t7feq4p3dc73f34j20')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh2ghmjts73cre2n0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 0.5;
n_shots = 3000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.14011973783337547 ± 0.014776552998535163
# Estimated V = 0.07908346999072974 ± 0.07676449340714703

# %% [markdown]
# h = 1, k = 1

# %%
# Sampler
jobS = service.job('d0t7fffp51os73b0pe2g') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh3775hms73dvlrlg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.31910678118654745 ± 0.016827120965869354
# Estimated B = 0.19638376369419475 ± 0.014339792533605237

# %%
# Extract results
jobS = service.job('d0t7ffg7m9ds739h0240')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh3ghmjts73cre2og')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1;
n_shots = 3000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.009786437626905072 ± 0.025639968798732964
# Estimated V = 0.3058087026658656 ± 0.02253591104135561

# %% [markdown]
# h = 1.5, k = 1

# %%
# Extract results
jobS = service.job('d0t7ffo7m9ds739h0250') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh4775hms73dvlrmg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1.5; k = 1;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.4870754415067658 ± 0.023599992937852053
# Estimated B = 0.17373510096542688 ± 0.061257194479750456

# %%
# Sampler
jobS = service.job('d0t7fga4p3dc73f34j3g')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh4iq9bic73bahaeg')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1.5; k = 1;
n_shots = 3000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

# Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = -0.18926627421620812 ± 0.027769677041027375
# Estimated V = 0.2693315593570177 ± 0.13430729521468765

# %% [markdown]
# h = 1; k = 1.5

# %%
# Sampler
jobS = service.job('d0t7fgi4p3dc73f34j40') 
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh5775hms73dvlrp0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1.5;
n_shots = 3000

# Energies
ene_A = (h**2)/(np.sqrt(h**2+k**2))
ene_B = (h**2)/(np.sqrt(h**2+k**2))
est_B = exp_value + ene_B

# Error arrays
error_A = []
error_B = []

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]

        ene_A += h*(-1)**int(bit_string[0])*count/n_shots
        ene_B += h*(-1)**int(bit_string[3])*count/n_shots 

        for i in range(count):
            error_A.append(h*(-1)**int(bit_string[0]))
            error_B.append(h*(-1)**int(bit_string[3]))

# Print results
print("H_B =",ene_B,"±",np.std(error_B)/np.sqrt(n_shots))
print("Estimated B =",est_B,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - H")
# Out:
# H_B = 0.25336686289189586 ± 0.017408793010259903
# Estimated B = 0.1076891495347343 ± 0.059108660449645564

# %%
# Extract results
jobS = service.job('d0t7fgvp51os73b0pe40')
result = jobS.result()[0]
counts = result.data.meas.get_counts()

# Estimator
jobT = service.job('d0qkh5g15afs73cmd8j0')
result = jobT.result()[0]
exp_value = result.data.evs
value_error = result.data.stds

# parameters
h = 1; k = 1.5;
n_shots = 3000

# Energies
ene_V=(2*k**2)/(np.sqrt(h**2+k**2))
est_V = exp_value + ene_V

# Error arrays
error_V=[]

# Calculate energies and errors
for orig_bit_string, count in counts.items():
        bit_string = orig_bit_string[::-1]
    
        ene_V += 2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3])*count/n_shots#

        for i in range(count):
            error_V.append(2*k*(-1)**int(bit_string[0])*(-1)**int(bit_string[3]))

#Print results
print("V =",ene_V,"±", np.std(error_V)/np.sqrt(n_shots))
print("Estimated V =",est_V,"±",value_error)

plot_histogram(counts, title=f"{jobS.backend().name} - V")
# Out:
# V = 0.26615088301353124 ± 0.03663832237789644
# Estimated V = 1.0360154972577518 ± 1.1330841418813369
